# %%
#factorial of a number
def fact(num):
    if(num==1):
        return 1
    return num * fact(num-1)

num=int(input("Enter the number: "))
fact(num)
# Out:
# Enter the number:  5
# 120

# %%
#sum of n natural numbers
def add(n):
        if n==0:
            return 0
        return n + add(n-1)
        


n=int(input("Enter the number: "))
add(n)
# Out:
# Enter the number:  5
# 15

# %%
# A online shopping application wants to calculate the square of different product quantities entered by user. Write a suitable program to perform the task
def sq(n):
    

n=int(input("Enter the number: "))
sq(n)

# %%
# A calculator application needs to perform multiplication of two numbers using a compact function. Write an appropriate solution

'''def mult(num1,num2):
    if num1 ==0 or num2==0:
        return 0
    return num1 + (num1, num2-1)







num1=int(input("Enter the first number: "))
num2=int(input("Enter the second number: "))
mult(num1,num2)'''




def mult(num1, num2):
    if num1 == 0 or num2 == 0:
        return 0
    if num2 == 1:
        return num1
    return num1 + mult(num1, num2 - 1)

num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

print("Multiplication =", mult(num1, num2))
# Out:
# Enter the first number:  5
# Enter the second number:  4
# Multiplication = 20

# %%
#Accept a name and print first character last character and length
a=input("Enter the name: ")
print(len(a))

print(a[0])
print(a[-1])
# Out:
# Enter the name:  Shivam
# 6
#
# S
# m

# %%
#Accept a city and print first three letter
city=input("Enter the city name: ")
print(city[:3])
# Out:
# Enter the city name:  asdfg
# asd

# %%
#Accept a college name and print last four letters.
clg= input("Enter the name: ")
print(clg[-4:])
# Out:
# Enter the name:  asdfghj
# fghj

# %%
#Accept a course ane and print middle three charaters
course=input("Enter the name: ")
print()

# %%
#Accept an email and print first five character
email=input("Enter the email: ")
print(email[:6])
# Out:
# Enter the email:  fjgjrgurgnsj
# fjgjrg

# %%
#Write a recursive function to find sum of all numbers in a list without using sum() or loops eg [12,5,7,10,8]-42
def sum(a):
    if len(a)==0:
        return 0
    return a[0]+ sum(a[1:])
    
a=[12,5,7,10,8]
sum(a)
# Out:
# 42

# %%
#Nested List Maximum
#write a recursive function to find the largest number in a nested array eg [10,[25,6],[7,[55,2],11],30]

# %%
#function returning function
#Create calculator(operation) that return another function eg add=calculator('add');add(5,3)=8
def add(a,b):
    if a==0 or b==0:
        return 1
    if b==1:
        return a
    if a==1:
        return b
    return a + add(a,b-1)
a=int(input("Enter the number: "))
b=int(input("Enter the number: "))
add(a,b)
# Out:
# Enter the number:  6
# Enter the number:  5
# 30

# %%
#Build your own map()
#Implement my_map(func,data) that behave like map() without using built-in-map()

def square(x):
    return x * x
numbers = [1, 2, 3, 4, 5]
output = my_map(square, numbers)
print(output)

# %%
#Recursive String compression
#Compress aaabbbccccdda into 'a3b3c4d2a1' using recursion only

# %%
#Lambda + filter()
#Give student tuples (Name,Marks,Age) display only students with marks >80 and age < 22 using lambda and filter()

# %%
#Recursive number to words
#Convert 5072 to "Five Zero Seven Two " using recursive only

# %%
#Build your own reduce
#Implement my_reduce(function,data) without using functools.reduce() eg lambdax,y:x+y on [2,4,6,8]-20

# %%
#Recursive Decimao to binary
#Convert a decimal number to binary using recursion only. Do not use bin().

# %%
#Employee Salary Processing
Given employee salary tuples: (1) Increase salary by 10% using map(),(2)Filter salaries>60000 using filter() , (3)Find total salary using reduce()
