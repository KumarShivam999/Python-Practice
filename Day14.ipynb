# %%
#File Handling
with open ("employees.txt","w") as file:
    file.write("101,Rahul,50000\n")
    file.write("102,Priya,62000\n")

with open ("employees.txt","r") as file:
    print(file.read())
# Out:
# 101,Rahul,50000
# 102,Priya,62000

# %%
# with open ("employees.txt","a") as file:
#     file.write("103,Shivam,50000\n")
#     file.write("104,Anil,62000\n")
# with open ("employees.txt","r") as file:
#     print(file.read())


#to delete the file 
import os

os.remove("emmployee.txt")

print("File deleted successfully.")
# Out:
# File deleted successfully.

# %%
#Create a file and write your introduction
#Read and display file content
#Append a new line
#Count number of lines
#Count  number of words
#Search a word
#Copy one file into another
#Convert file content to uppercase
#Store 5 student names
#Read alternate lines
#create a file and write about yourself
with open ("shivam.txt","w") as file:
    file.write("12317115,Shivam,Bihar,Btech CSE\n")

#to read the files
with open ("shivam.txt","r") as file:   
    print(file.read())

#update the files
with open ("shivam.txt","a") as file:
    file.write("9153108448")
with open ("shivam.txt","r") as file:
    print(file.read())

#count number of lines
with open("shivam.txt", "r") as file:
    lines = file.readlines()

print("Number of lines:", len(lines))


#count number of words
with open("shivam.txt", "r") as file:
    text = file.read()

words = text.split()

print("Number of words:", len(words))


#to search the word
word = input("Enter word to search: ")
with open("shivam.txt", "r") as file:
    text = file.read()

if word in text:
    print("Word Found")
else:
    print("Word Not Found")

#copy the file
with open("shivam.txt", "r") as file:
    data = file.read()

with open("employees.txt", "w") as file:
    file.write(data)

print("File copied successfully.")

#convert in uppercase
with open("shivam.txt", "r") as file:
    data = file.read()

print(data.upper())


#store 5 names
with open("students.txt", "w") as file:
    for i in range(5):
        name = input("Enter student name: ")
        file.write(name + "\n")




#Read the alternate lines
with open("students.txt", "r") as file:
    lines = file.readlines()

print("Alternate Lines:")
for i in range(0, len(lines), 2):
    print(lines[i], end="")
# Out:
# 12317115,Shivam,Bihar,Btech CSE
#
# 12317115,Shivam,Bihar,Btech CSE
# 9153108448
# Number of lines: 2
# Number of words: 3
# Enter word to search:  Shivam
# Word Found
# File copied successfully.
# 12317115,SHIVAM,BIHAR,BTECH CSE
# 9153108448
# Enter student name:  chotu
# Enter student name:  bauna
# Enter student name:  ghoda
# Enter student name:  moti
# Enter student name:  booty
# Alternate Lines:
# chotu
# ghoda
# booty

# %%
with open("shivam.txt", "r") as file:
    data = file.read()

print(data.upper())
# Out:
# 12317115,SHIVAM,BIHAR,BTECH CSE
# 9153108448

# %%
with open ("shivam.txt","r") as file:
    text=file.read()
    words=text.split()
print("Number of words: ",len(text))
print("Number of lines: ",len(words))
# Out:
# Number of words:  42
# Number of lines:  3

# %%
#oops
class Student:
    college="LPU"
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(self):
        print(self.name,self.age,self.college)
s1=Student("Rahul",20)
s2=Student("Amit",21)

s1.display()
s2.display()
# Out:
# Rahul 20 LPU
# Amit 21 LPU
