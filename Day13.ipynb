# %%
#Given a sentence display the frequency of every character

# %%
#Remove all duplicate roll numbers while preserving the original order

roll_numbers=[]
a=int(input("Enter the number: "))
for i in range (a):
    value=int(input("Enter the roll number "))
    roll_numbers.append(value)
print (set(roll_numbers))
# Out:
# Enter the number:  5
# Enter the roll number  1
# Enter the roll number  2
# Enter the roll number  3
# Enter the roll number  4
# Enter the roll number  4
# {1, 2, 3, 4}

# %%
#Store monthly rainfall value and print rainfall of the last three 
rainfall=[]
for i in range(5):
    value=int(input("Enter the amount of rainfall:" ))
    rainfall.append(value)
print(rainfall[-3:])
# Out:
# Enter the amount of rainfall: 45
# Enter the amount of rainfall: 54
# Enter the amount of rainfall: 34
# Enter the amount of rainfall: 45
# Enter the amount of rainfall: 56
# [34, 45, 56]

# %%
#Maintain a simple contact directory supporting search by name
contact={}
for i in range(5):
    name=input("Enter the name: ")
    number=input("Enter the contacct number: ")
    contact[name]=number
print(contact)

search=input("Enter the name u want to search: ")
if search in contact:
    print("details:",contact[search])
else:
    print("Not found")
# Out:
# Enter the name:  Shivam
# Enter the contacct number:  9153108448
# Enter the name:  Aditi
# Enter the contacct number:  7070808372
# Enter the name:  Papa
# Enter the contacct number:  8709313093
# Enter the name:  M
# Enter the contacct number:  45678
# Enter the name:  jgjvk
# Enter the contacct number:  0987654
# {'Shivam': '9153108448', 'Aditi': '7070808372', 'Papa': '8709313093', 'M': '45678', 'jgjvk': '0987654'}
# Enter the name u want to search:  Aditi
# details: 7070808372

# %%
#Given marks of students print names of students scoring above class average
total_marks={}
a=int(input("Enter the number: "))
sum=0
for i in range(a):
    name=input("Enter the name: ")
    value=int(input("Entert he marks: "))
    total_marks[name]=value
    sum+=value
print(marks)

av=float(sum/len(marks))
print(av)

if value>av:
    print(total_marks)
else:
    print("Low scored")
# Out:
# Enter the number:  3
# Enter the name:  a
# Entert he marks:  50
# Enter the name:  b
# Entert he marks:  60
# Enter the name:  c
# Entert he marks:  70
# [50, 60, 70]
# 60.0
# {'a': 50, 'b': 60, 'c': 70}

# %%
#Design a mini social_network data model supporting friends mutual friends and friend suggestion

# %%
#Build a recommendation engine that suggests products purchased by similar customers but not by the current customer

# %%
#Create an airline reservation model and detect double booked seat.

# %%
#Develop an online coding contest scoreboard supporting rank update after every submission

# %%
#Build a plagarism checker that compares two assignment based on unique words and similarity percentage.

# %%
#handle division by zero

try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))

    print("Result:", a / b)

except ZeroDivisionError:
    print("Cannot divide by zero.")

# %%
#handle invalid age input
try:
    age = int(input("Enter your age: "))
    print("Your age is", age)

except ValueError:
    print("Please enter a valid age.")

# %%
#handle list index error
numbers = [10, 20, 30, 40]

try:
    index = int(input("Enter index: "))
    print(numbers[index])

except IndexError:
    print("Invalid index.")

# %%
#Handle dictionary key error
student = {
    "Name": "Shivam",
    "Age": 20
}

try:
    key = input("Enter key: ")
    print(student[key])

except KeyError:
    print("Key not found.")

# %%
#Handle file not found
try:
    file = open("data.txt", "r")
    print(file.read())
    file.close()

except FileNotFoundError:
    print("File does not exist.")

# %%
#Calculator using try-except
try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))

    op = input("Enter operator (+,-,*,/): ")

    if op == "+":
        print(a + b)

    elif op == "-":
        print(a - b)

    elif op == "*":
        print(a * b)

    elif op == "/":
        print(a / b)

    else:
        print("Invalid operator.")

except ZeroDivisionError:
    print("Cannot divide by zero.")

except ValueError:
    print("Enter valid numbers.")

# %%
#Validate salary >0
try:
    salary = float(input("Enter salary: "))

    if salary > 0:
        print("Valid Salary")
    else:
        print("Salary must be greater than 0.")

except ValueError:
    print("Invalid salary.")

# %%
#Validate passwoed length
password = input("Enter password: ")

try:
    if len(password) < 8:
        raise ValueError

    print("Password Accepted")

except ValueError:
    print("Password must contain at least 8 characters.")

# %%
#Employee bonus calculator
try:
    salary = float(input("Enter salary: "))

    if salary < 0:
        raise ValueError

    bonus = salary * 0.10

    print("Bonus =", bonus)

except ValueError:
    print("Invalid salary.")

# %%
#shopping bill with invalid quantity
try:
    price = float(input("Enter price: "))
    quantity = int(input("Enter quantity: "))

    if quantity <= 0:
        raise ValueError

    bill = price * quantity

    print("Total Bill =", bill)

except ValueError:
    print("Quantity must be greater than 0.")
# Out:
# Enter price:  45
# Enter quantity:  2
# Total Bill = 90.0

# %%
try:
    a=int(input("Enter the number: "))
    b=int(input("Enter the number: "))
    print("Result: ",a/b)

except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Enter the number:  4
# Enter the number:  2
# Result:  2.0

# %%
try:
    age=int(input("Enter the age: ))
    print("Age is: ",age)
                  except ValueError:
        print("Enter valid age")
# Out:
#   Cell In[54], line 2
#     age=int(input("Enter the age: ))
#                   ^
# SyntaxError: unterminated string literal (detected at line 2)
