# %%
#wap to print number is positive or negative
num1=int(input("Enter the number: "))
if num1>0:
    print("positive")
elif num1==0:
    print("zero")
else:
    print("negative")
# Out:
# Enter the number:  0
# zero
