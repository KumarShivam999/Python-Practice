# %%
a=int(input("Enter the number: "))
if (a>0):{
    print("positive")
}

else:{
    print("negative")
}
# Out:
# Enter the number:  -25
# negative

# %%
a=int(input("Enter the number"))
if a>0 and a<1000:
    print("Discout of 10%")
    discount=a*0.10
    final_amount=a-discount
    print("Discount amount:",discount)
    print("Final_amount: ",final_amount)
elif a>1000 and a<2000:
    print("Discount of 13%")
    discount=a*0.13
    final_amount=a-discount
    print("Discount amount:",discount)
    print("Final_amount: ",final_amount)
    
else:
    print("Discount of 18%");
    discount=a*0.18
    final_amount=a-discount
    print("Discount amount:",discount)
    print("Final_amount: ",final_amount)
# Out:
# Enter the number 2500
# Discount of 18%
# Discount amount: 450.0
# Final_amount:  2050.0

# %%
user=input("Enter the name")
pwd=input("Enter the password")
if user=="Shivam" and pwd=="2006":
    print("Welcome ")
else:
    print("Wrong Credentials")
    print("Try Again")
# Out:
# Enter the name ff;sd
# Enter the password jffs
# Wrong Credentials
# Try Again

# %%
correct_username = "shivam"
correct_password = "2006"

attempts = 3

while attempts > 0:
    username = input("Enter username: ")
    password = input("Enter password: ")

    if username == correct_username and password == correct_password:
        print("Welcome! Login Successful.")
        break
    else:
        attempts = attempts - 1

        if attempts > 0:
            print("Invalid credentials.")
            print("You have", attempts, "attempt(s) left.\n")
        else:
            print("Sorry! You have used all your attempts.")
            print("Program Closed.")
# Out:
# Enter username:  ghds
# Enter password:  4573
# Invalid credentials.
# You have 2 attempt(s) left.
# Enter username:  gfdkhfs
# Enter password:  ghs
# Invalid credentials.
# You have 1 attempt(s) left.
# Enter username:  ggfbsh
# Enter password:  fhgj
# Sorry! You have used all your attempts.
# Program Closed.

# %%
#### user="Shivam"
# password="2006"
total_amount=int(input("Enter the total amount"))
users=input("Enter your usename")
password=input("Enter password")

if user=="Shivam" and password=="2006":
    print("Welcome to ATM.")
    amount_credit=int(input("Enter the amount u want to credit"))
    if amount_credit<total_amount:
        remaining_amount=total_amount-amount_credit
        print("Total Amount",total_amount)
        print("Amount Credit",amount_credit)
        print("Remaining_Amount",remaining_amount)
    else:
        print("Not Sufficient Amount")

else:
    print("Invalid Credentials")
# Out:
# Enter the total amount 1000
# Enter your usename Shivam
# Enter password 2006
# Welcome to ATM.
# Enter the amount u want to credit 500
# Total Amount 1000
# Amount Credit 500
# Remaining_Amount 500
